# %%
import pandas as pd

# %%
def extractJobs(path, adjust=0):
    jobs = []
    with open(path) as f:
        data = f.read()[:-1] # do not include "\n"
        for row in data.split("\n"):     # each row in the file
            row_list = row.split(",")    # split each line with ","
            if(len(row_list[0]) != 0):   # if the row has a value
                jobs.append(row_list[1+adjust]) # append the job to jobs list
    return jobs[1-adjust:]

def oldJobs(path,adjust=1):

    with open(path,'w+') as f:
        read_char = f.read(1)
        
        if (not read_char):
            return []
    return extractJobs(path,adjust)

def register(df,old_jobs):
    for i in range(len(df)):
        df["Ticket"] = df.iloc[i]["Name"] in old_jobs # save False if no record of this job found

    return df

def merge(paths):
    jobs = []

    for i in paths:
        jobs += extractJobs(i)

    return [i for i in jobs if (len(i) != 0)]

def concat_df(paths, old_jobs):

    df = pd.DataFrame()

    for path in paths:
        df_i = pd.read_csv(path)
        df_i = register(df_i, old_jobs)
        df = pd.concat([df,df_i],ignore_index=True)
    
    return df

# %%
old_path = "csv/jobs.csv"
paths = ["csv/coderspace.csv","csv/tcmb.csv"]

# %%
new_jobs = merge(paths)

# %%
old_jobs = oldJobs(old_path)

# %%
df = concat_df(paths, old_jobs)

# %%
df
# Out:
#                                                 Type  \
# 0                                   Hiring Challenge
# 1                                 Hackathon-Datathon
# 2                                            Meet-up
# 3                                   Yetenek Programı
# 4                                           Bootcamp
# 5                                 Hackathon-Datathon
# 6                                   Yetenek Programı
# 7  BT Müfettiş Yardımcısı Olarak Görev Yapmak Üze...
# 8  Bilişim Uzman Yardımcısı Olarak Görev Yapmak Ü...
# 9  Türkiye Cumhuriyet Merkez Bankasına Çevirmen A...
#
#                                                 Name  Status        Date  \
# 0                Türkiye Sigorta Hiring Challenge #3    True   8 Haziran
# 1               Bursa Akıllı Şehir Deprem Hackathonu    True  11 Haziran
# 2                            Product Management Camp    True  13 Haziran
# 3  Sabancı SEED Digital Genç Yetenek İşe Alım Pro...   False    23 Nisan
# 4  Akbank & Microsoft AI Academy Data Analyst Eği...   False     15 Mart
# 5                                Shell Datathon 2023   False    16 Mayıs
# 6                            Softtech Yetenek Kuşağı   False    28 Mayıs
# 7                             BT Müfettiş Yardımcısı   False  18/05/2023
# 8                           Bilişim Uzman Yardımcısı   False  18/05/2023
# 9                                                NaN   False  18/05/2023
#
#          Site  Ticket
# 0  Coderspace   False
# 1  Coderspace   False
# 2  Coderspace   False
# 3  Coderspace   False
# 4  Coderspace   False
# 5  Coderspace   False
# 6  Coderspace   False
# 7        TCMB   False
# 8        TCMB   False
# 9        TCMB   False

# %%
df.to_csv("csv/jobs.csv")
